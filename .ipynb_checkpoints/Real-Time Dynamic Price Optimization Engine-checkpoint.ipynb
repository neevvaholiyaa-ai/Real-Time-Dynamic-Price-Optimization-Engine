# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("data/dataset.csv")
df
# Out:
#            Product_ID                              Product_Name       Brand  \
# 0       PROD-ELEC-001  Wireless Noise Cancelling Headphones Pro  SoundPulse
# 1       PROD-ELEC-001  Wireless Noise Cancelling Headphones Pro  SoundPulse
# 2       PROD-ELEC-001  Wireless Noise Cancelling Headphones Pro  SoundPulse
# 3       PROD-ELEC-001  Wireless Noise Cancelling Headphones Pro  SoundPulse
# 4       PROD-ELEC-001  Wireless Noise Cancelling Headphones Pro  SoundPulse
# ...               ...                                       ...         ...
# 145893  PROD-SPOR-120   Push-Up Stand Bars with Cushioned Grips    IronCore
# 145894  PROD-SPOR-120   Push-Up Stand Bars with Cushioned Grips    IronCore
# 145895  PROD-SPOR-120   Push-Up Stand Bars with Cushioned Grips    IronCore
# 145896  PROD-SPOR-120   Push-Up Stand Bars with Cushioned Grips    IronCore
# 145897  PROD-SPOR-120   Push-Up Stand Bars with Cushioned Grips    IronCore
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145898 entries, 0 to 145897
# Data columns (total 71 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Product_ID                    145898 non-null  object
#  1   Product_Name                  145898 non-null  object
#  2   Brand                         145898 non-null  object
#  3   Category                      145898 non-null  object
#  4   Subcategory                   145898 non-null  object
#  5   SKU                           145898 non-null  object
#  6   City                          145898 non-null  object
#  7   Date                          145898 non-null  object
#  8   Day_of_Week                   145898 non-null  int64
#  9   Month                         145898 non-null  int64
#  10  Quarter                       145898 non-null  int64
#  11  Is_Weekend                    145898 non-null  bool
# ...

# %%
df.isnull().sum()
# Out:
# Product_ID                0
# Product_Name              0
# Brand                     0
# Category                  0
# Subcategory               0
#                          ..
# Demand_Momentum_7d        0
# Revenue_Per_Unit          0
# Price_Rank_in_Category    0
# Fuel_Price_INR_Proxy      0
# Optimal_Price             0
# Length: 71, dtype: int64

# %%
df.describe()
# Out:
#          Day_of_Week          Month        Quarter  Days_Until_Next_Festival  \
# count  145898.000000  145898.000000  145898.000000             145898.000000
# mean        3.008376       6.337208       2.452467                 26.957313
# std         1.999767       3.327746       1.089386                 27.837644
# min         0.000000       1.000000       1.000000                  0.000000
# 25%         1.000000       4.000000       2.000000                  6.000000
# 50%         3.000000       6.000000       2.000000                 16.000000
# 75%         5.000000       9.000000       3.000000                 39.000000
# max         6.000000      12.000000       4.000000                117.000000
#
#        Days_Since_Launch  Days_Since_Last_Price_Change            MRP  \
# count      145898.000000                 145898.000000  145898.000000
# mean          328.028774                      3.266015    1516.297783
# ...
